# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !rm -rf sample_data

# %%
# %cd /content
# !rm -rf /content/FinalProject
# !rm -rf /content/sample_data
# Out:
# /content

# %%
# !unzip drive/MyDrive/FinalProject.zip -d ./
# Out:
# Archive:  drive/MyDrive/FinalProject.zip
#    creating: ./FinalProject/
#    creating: ./FinalProject/.git/
#   inflating: ./FinalProject/.gitignore
#  extracting: ./FinalProject/.git/COMMIT_EDITMSG
#   inflating: ./FinalProject/.git/config
#   inflating: ./FinalProject/.git/description
#   inflating: ./FinalProject/.git/FETCH_HEAD
#  extracting: ./FinalProject/.git/HEAD
#    creating: ./FinalProject/.git/hooks/
#   inflating: ./FinalProject/.git/hooks/applypatch-msg.sample
#   inflating: ./FinalProject/.git/hooks/commit-msg.sample
#   inflating: ./FinalProject/.git/hooks/fsmonitor-watchman.sample
#   inflating: ./FinalProject/.git/hooks/post-update.sample
#   inflating: ./FinalProject/.git/hooks/pre-applypatch.sample
#   inflating: ./FinalProject/.git/hooks/pre-commit.sample
#   inflating: ./FinalProject/.git/hooks/pre-merge-commit.sample
#   inflating: ./FinalProject/.git/hooks/pre-push.sample
#   inflating: ./FinalProject/.git/hooks/pre-rebase.sample
# ...

# %%
# %cd /content/FinalProject
# Out:
# /content/FinalProject

# %%
import os 
import pandas as pd
os.makedirs("results", exist_ok=True) 

results = pd.DataFrame(columns =['ElapsedTime', 'GlobalPatternLoss', 'AveragePatternLoss', 'GlobalValueLoss', 'MeanValueLoss']) 
  
results.loc[0]=[ 5.5, 2, 10.5, 2.5, 5]

results.to_csv('./results/ciao.csv', sep ='\t')

# %%
results.head()
# Out:
#    ElapsedTime  GlobalPatternLoss  ...  GlobalValueLoss  MeanValueLoss
# 0          5.5                2.0  ...              2.5            5.0
#
# [1 rows x 5 columns]

# %%
# !pip install loguru
# !pip install saxpy
# Out:
# ...
#      |████████████████████████████████| 184kB 8.5MB/s
# ...
#      |████████████████████████████████| 245kB 13.6MB/s
# ...
#   Created wheel for saxpy: filename=saxpy-1.0.1.dev167-cp37-none-any.whl size=17671 sha256=5ae7c9fd65ce25182887ba96d72a1e3133953888e9b8ff0b82e5f5766dabc7c0
#   Stored in directory: /root/.cache/pip/wheels/68/d1/a0/a2a4f96eb82607654bc45f00479af34ddd7c45be9096b8e63c
# Successfully built saxpy
# ERROR: datascience 0.10.6 has requirement coverage==3.7.1, but you'll have coverage 5.5 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: coveralls 0.5 has requirement coverage<3.999,>=3.6, but you'll have coverage 5.5 which is incompatible.
# ERROR: pytest-cov 2.11.1 has requirement pytest>=4.6, but you'll have pytest 3.6.4 which is incompatible.
# ...
#   Found existing installation: coverage 3.7.1
#     Uninstalling coverage-3.7.1:
#       Successfully uninstalled coverage-3.7.1
# ...

# %%
# !python ./k_P_anonymity.py kapra 128 6 6 1 ./data/facebook_microsoft.csv
# Out:
# 2021-03-01 22:12:08.064 | INFO     | includes.io:load_dataset:112 - Loading dataset...
# 2021-03-01 22:12:08.282 | INFO     | includes.io:load_dataset:132 - Extracted attribute TS144 as sensitive data
# 2021-03-01 22:12:19.487 | INFO     | includes.io:load_dataset:146 - Loaded dataset
# 2021-03-01 22:12:19.488 | INFO     | includes.kapra:KAPRA:49 - Start KAPRA create-tree phase ...
# 2021-03-01 22:15:47.953 | INFO     | includes.kapra:KAPRA:57 - End KAPRA create-tree phase
# 2021-03-01 22:15:47.953 | INFO     | includes.kapra:KAPRA:59 - Start group formation phase ...

# %% [markdown]
# ## NAIVE

# %%
# !python ./k_P_anonymity.py naive 16 12 6 1 ./data/facebook_microsoft.csv
# !python ./k_P_anonymity.py naive 16 12 6 1 ./data/facebook_palestine.csv
# !python ./k_P_anonymity.py naive 16 12 6 1 ./data/sales_transactions_dataset_weekly.csv

# %%
# !python ./k_P_anonymity.py naive 6 128 6 1 ./data/facebook_microsoft.csv
# !python ./k_P_anonymity.py naive 6 128 6 1 ./data/facebook_palestine.csv
# !python ./k_P_anonymity.py naive 6 128 6 1 ./data/sales_transactions_dataset_weekly.csv
